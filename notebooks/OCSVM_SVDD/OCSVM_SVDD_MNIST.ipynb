# %%
# from google.colab import drive
# drive.mount('/content/drive')
# !pip install picklable_itertools

# !pip install fuel
# !pip install foolbox

# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
import numpy as np
# PROJECT_DIR = "/content/drive/My Drive/2018/Colab_Deep_Learning/one_class_neural_networks/"
PROJECT_DIR = "/home/thinhbka/Desktop/oc-nn/"
import sys,os
import numpy as np
sys.path.append(PROJECT_DIR)

# %% [markdown]
# ##** MNIST 3 Vs All  **##

# %%
## Obtaining the training and testing data
# %reload_ext autoreload
# %autoreload 2

import numpy as np 
from src.config import Configuration as Cfg
from src.models.svm import SVM


DATASET = "mnist"
ESTIMATORS = 100
MAX_SAMPLES = 250
CONTAMINATION = 0.1
MODEL_SAVE_PATH = PROJECT_DIR + "models/mnist/ISO_FOREST/"
REPORT_SAVE_PATH = PROJECT_DIR + "/reports/figures/mnist/ISO_FOREST/"

PRETRAINED_WT_PATH = ""
RANDOM_SEED = [42,56,81,67,33,25,90,77,15,11]
AUC = []


## Setting the required config values
Cfg.out_frac = 0.1
Cfg.ad_experiment = 1                 # 1 : yes # 0 : No
Cfg.unit_norm_used = "l1"
Cfg.gcn = 1                           # 1 : yes # 0 : No
Cfg.zca_whitening = 0                  # 1 : yes # 0 : No
Cfg.pca = 0 # 1 for yes # 0 : No
Cfg.mnist_val_frac = 0.1
Cfg.mnist_normal = 3
Cfg.mnist_outlier = -1


 # SVM parameters
Cfg.svm_nu = 0.1
Cfg.svm_GridSearchCV = 1

for seed in RANDOM_SEED:  
    
   # plot parameters
   # Cfg.xp_path = REPORT_SAVE_PATH

    # dataset
    Cfg.seed = seed
    
    
    # initialize OC-SVM
    ocsvm = SVM(loss="OneClassSVM", dataset=DATASET, kernel="rbf")

    # train OC-SVM model
    ocsvm.fit(GridSearch=Cfg.svm_GridSearchCV)

    # predict scores
    auc_roc = ocsvm.predict(which_set='test')
   
    print("========================================================================",)
    print("AUROC: ",auc_roc)
    print("========================================================================",)
    AUC.append(auc_roc)

    
print("===========AURO Computed============================")
print("AUROC computed ", AUC)
auc_roc_mean = np.mean(np.asarray(AUC))
auc_roc_std = np.std(np.asarray(AUC))
print ("AUROC =====", auc_roc_mean*100 ,"+/-",auc_roc_std*100)
print("========================================================================")
# Out:
# Using TensorFlow backend.
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /home/thinhbka/Desktop/oc-nn/data/mnist/reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  3
# [INFO] : The idx_normal is:  [False False False ... False False False]
# [INFO] : The idx_outlier is:  [ True  True  True ...  True  True  True]
# [INFO:] Random Seed used is   42
# [INFO] : The idx_normal is:  [False False False ... False False False]
# [INFO] : The idx_outlier is:  [ True  True  True ...  True  True  True]
# [INFO: ] Data loaded.
# WARNING:tensorflow:From /home/thinhbka/.local/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/thinhbka/.local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:1062: calling reduce_prod_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6593, 28, 28, 1)
# The shape of POS data :  (6528, 28, 28, 1)
# The shape of NEG data :  (65, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.685849
# Starting prediction...
# Total elapsed time: 0.707101
# Starting prediction...
# Total elapsed time: 0.687572
# Starting prediction...
# Total elapsed time: 0.696098
# Starting prediction...
# Total elapsed time: 0.707911
# Starting prediction...
# Total elapsed time: 0.79347
# Starting prediction...
# Total elapsed time: 2.24863
# Starting prediction...
# Total elapsed time: 5.89139
# Starting prediction...
# Total elapsed time: 6.70055
# Starting prediction...
# Total elapsed time: 7.65649
# Total elapsed time: 7.65661
# Starting prediction...
# Total elapsed time: 6.61006
# ========================================================================
# AUROC:  0.8759063730450851
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /home/thinhbka/Desktop/oc-nn/data/mnist/reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  3
# [INFO] : The idx_normal is:  [False False False ... False False False]
# [INFO] : The idx_outlier is:  [ True  True  True ...  True  True  True]
# [INFO:] Random Seed used is   56
# [INFO] : The idx_normal is:  [False False False ... False False False]
# [INFO] : The idx_outlier is:  [ True  True  True ...  True  True  True]
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6593, 28, 28, 1)
# The shape of POS data :  (6528, 28, 28, 1)
# The shape of NEG data :  (65, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.90794
# Starting prediction...
# Total elapsed time: 0.994331
# Starting prediction...
# Total elapsed time: 0.740979
# Starting prediction...
# Total elapsed time: 0.693589
# Starting prediction...
# Total elapsed time: 0.732949
# Starting prediction...
# Total elapsed time: 0.797515
# Starting prediction...
# Total elapsed time: 2.23733
# Starting prediction...
# Total elapsed time: 5.93073
# Starting prediction...
# Total elapsed time: 7.33681
# Starting prediction...
# Total elapsed time: 6.83528
# Total elapsed time: 6.83539
# Starting prediction...
# Total elapsed time: 6.48418
# ========================================================================
# AUROC:  0.834281918085822
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /home/thinhbka/Desktop/oc-nn/data/mnist/reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  3
# [INFO] : The idx_normal is:  [False False False ... False False False]
# [INFO] : The idx_outlier is:  [ True  True  True ...  True  True  True]
# [INFO:] Random Seed used is   81
# [INFO] : The idx_normal is:  [False False False ... False False False]
# [INFO] : The idx_outlier is:  [ True  True  True ...  True  True  True]
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6593, 28, 28, 1)
# The shape of POS data :  (6528, 28, 28, 1)
# The shape of NEG data :  (65, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.99777
# Starting prediction...
# Total elapsed time: 0.850958
# Starting prediction...
# Total elapsed time: 0.973548
# Starting prediction...
# Total elapsed time: 1.07876
# Starting prediction...
# Total elapsed time: 0.974839
# Starting prediction...
# Total elapsed time: 0.835895
# Starting prediction...
# Total elapsed time: 1.89859
# Starting prediction...
# Total elapsed time: 6.46265
# Starting prediction...
# Total elapsed time: 8.20285
# Starting prediction...
# Total elapsed time: 8.57532
# Total elapsed time: 8.57543
# Starting prediction...
# Total elapsed time: 8.01833
# ========================================================================
# AUROC:  0.8639090251861116
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /home/thinhbka/Desktop/oc-nn/data/mnist/reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  3
# [INFO] : The idx_normal is:  [False False False ... False False False]
# [INFO] : The idx_outlier is:  [ True  True  True ...  True  True  True]
# [INFO:] Random Seed used is   67
# [INFO] : The idx_normal is:  [False False False ... False False False]
# [INFO] : The idx_outlier is:  [ True  True  True ...  True  True  True]
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6593, 28, 28, 1)
# The shape of POS data :  (6528, 28, 28, 1)
# The shape of NEG data :  (65, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.713029
# Starting prediction...
# Total elapsed time: 0.693047
# Starting prediction...
# Total elapsed time: 0.849044
# Starting prediction...
# Total elapsed time: 0.911286
# Starting prediction...
# Total elapsed time: 0.70755
# Starting prediction...
# Total elapsed time: 0.787503
# Starting prediction...
# Total elapsed time: 1.95127
# Starting prediction...
# Total elapsed time: 6.17677
# Starting prediction...
# Total elapsed time: 7.68474
# Starting prediction...
# Total elapsed time: 8.42367
# Total elapsed time: 8.42419
# Starting prediction...
# Total elapsed time: 7.10602
# ========================================================================
# AUROC:  0.8749092044035864
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /home/thinhbka/Desktop/oc-nn/data/mnist/reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  3
# [INFO] : The idx_normal is:  [False False False ... False False False]
# [INFO] : The idx_outlier is:  [ True  True  True ...  True  True  True]
# [INFO:] Random Seed used is   33
# [INFO] : The idx_normal is:  [False False False ... False False False]
# [INFO] : The idx_outlier is:  [ True  True  True ...  True  True  True]
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6593, 28, 28, 1)
# The shape of POS data :  (6528, 28, 28, 1)
# The shape of NEG data :  (65, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.866462
# Starting prediction...
# Total elapsed time: 0.720167
# Starting prediction...
# Total elapsed time: 0.687035
# Starting prediction...
# Total elapsed time: 0.692628
# Starting prediction...
# Total elapsed time: 0.694234
# Starting prediction...
# Total elapsed time: 1.33336
# Starting prediction...
# Total elapsed time: 2.09004
# Starting prediction...
# Total elapsed time: 6.89844
# Starting prediction...
# Total elapsed time: 9.24519
# Starting prediction...
# Total elapsed time: 7.36403
# Total elapsed time: 7.36416
# Starting prediction...
# Total elapsed time: 6.87881
# ========================================================================
# AUROC:  0.8639600447188062
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /home/thinhbka/Desktop/oc-nn/data/mnist/reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  3
# [INFO] : The idx_normal is:  [False False False ... False False False]
# [INFO] : The idx_outlier is:  [ True  True  True ...  True  True  True]
# [INFO:] Random Seed used is   25
# [INFO] : The idx_normal is:  [False False False ... False False False]
# [INFO] : The idx_outlier is:  [ True  True  True ...  True  True  True]
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6593, 28, 28, 1)
# The shape of POS data :  (6528, 28, 28, 1)
# The shape of NEG data :  (65, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.687364
# Starting prediction...
# Total elapsed time: 0.683534
# Starting prediction...
# Total elapsed time: 1.02276
# Starting prediction...
# Total elapsed time: 0.895699
# Starting prediction...
# Total elapsed time: 0.707067
# Starting prediction...
# Total elapsed time: 0.887475
# Starting prediction...
# Total elapsed time: 2.3562
# Starting prediction...
# Total elapsed time: 6.89994
# Starting prediction...
# Total elapsed time: 7.33445
# Starting prediction...
# Total elapsed time: 8.36175
# Total elapsed time: 8.36184
# Starting prediction...
# Total elapsed time: 7.6471
# ========================================================================
# AUROC:  0.8510699703494872
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /home/thinhbka/Desktop/oc-nn/data/mnist/reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  3
# [INFO] : The idx_normal is:  [False False False ... False False False]
# [INFO] : The idx_outlier is:  [ True  True  True ...  True  True  True]
# [INFO:] Random Seed used is   90
# [INFO] : The idx_normal is:  [False False False ... False False False]
# [INFO] : The idx_outlier is:  [ True  True  True ...  True  True  True]
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6593, 28, 28, 1)
# The shape of POS data :  (6528, 28, 28, 1)
# The shape of NEG data :  (65, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.743186
# Starting prediction...
# Total elapsed time: 0.911915
# Starting prediction...
# Total elapsed time: 0.861256
# Starting prediction...
# Total elapsed time: 0.998823
# Starting prediction...
# Total elapsed time: 0.69889
# Starting prediction...
# Total elapsed time: 0.83788
# Starting prediction...
# Total elapsed time: 1.97124
# Starting prediction...
# Total elapsed time: 5.8637
# Starting prediction...
# Total elapsed time: 8.51794
# Starting prediction...
# Total elapsed time: 8.06315
# Total elapsed time: 8.06325
# Starting prediction...
# Total elapsed time: 6.57102
# ========================================================================
# AUROC:  0.8355436386335263
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /home/thinhbka/Desktop/oc-nn/data/mnist/reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  3
# [INFO] : The idx_normal is:  [False False False ... False False False]
# [INFO] : The idx_outlier is:  [ True  True  True ...  True  True  True]
# [INFO:] Random Seed used is   77
# [INFO] : The idx_normal is:  [False False False ... False False False]
# [INFO] : The idx_outlier is:  [ True  True  True ...  True  True  True]
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6593, 28, 28, 1)
# The shape of POS data :  (6528, 28, 28, 1)
# The shape of NEG data :  (65, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.678505
# Starting prediction...
# Total elapsed time: 0.675796
# Starting prediction...
# Total elapsed time: 0.676528
# Starting prediction...
# Total elapsed time: 0.74641
# Starting prediction...
# Total elapsed time: 0.792986
# Starting prediction...
# Total elapsed time: 0.789446
# Starting prediction...
# Total elapsed time: 2.11668
# Starting prediction...
# Total elapsed time: 5.9572
# Starting prediction...
# Total elapsed time: 8.24846
# Starting prediction...
# Total elapsed time: 6.69484
# Total elapsed time: 6.69494
# Starting prediction...
# Total elapsed time: 6.13563
# ========================================================================
# AUROC:  0.8627673059317857
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /home/thinhbka/Desktop/oc-nn/data/mnist/reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  3
# [INFO] : The idx_normal is:  [False False False ... False False False]
# [INFO] : The idx_outlier is:  [ True  True  True ...  True  True  True]
# [INFO:] Random Seed used is   15
# [INFO] : The idx_normal is:  [False False False ... False False False]
# [INFO] : The idx_outlier is:  [ True  True  True ...  True  True  True]
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6593, 28, 28, 1)
# The shape of POS data :  (6528, 28, 28, 1)
# The shape of NEG data :  (65, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.68417
# Starting prediction...
# Total elapsed time: 0.688182
# Starting prediction...
# Total elapsed time: 0.690861
# Starting prediction...
# Total elapsed time: 0.692103
# Starting prediction...
# Total elapsed time: 0.704769
# Starting prediction...
# Total elapsed time: 0.78471
# Starting prediction...
# Total elapsed time: 1.8681
# Starting prediction...
# Total elapsed time: 5.69484
# Starting prediction...
# Total elapsed time: 6.97217
# Starting prediction...
# Total elapsed time: 6.69483
# Total elapsed time: 6.69493
# Starting prediction...
# Total elapsed time: 6.07944
# ========================================================================
# AUROC:  0.8669877090598762
# ========================================================================
# Inside the MNIST_DataLoader RCAE.RESULT_PATH: /home/thinhbka/Desktop/oc-nn/data/mnist/reports/figures/MNIST/RCAE/
# [INFO: ] Loading data...
# [INFO:] The  label  of normal points are  3
# [INFO] : The idx_normal is:  [False False False ... False False False]
# [INFO] : The idx_outlier is:  [ True  True  True ...  True  True  True]
# [INFO:] Random Seed used is   11
# [INFO] : The idx_normal is:  [False False False ... False False False]
# [INFO] : The idx_outlier is:  [ True  True  True ...  True  True  True]
# [INFO: ] Data loaded.
# [INFO:] Assertions of memory muted
# The shape of Training data :  (6593, 28, 28, 1)
# The shape of POS data :  (6528, 28, 28, 1)
# The shape of NEG data :  (65, 28, 28, 1)
# Starting training...
# Using GridSearchCV for hyperparameter selection...
# Starting prediction...
# Total elapsed time: 0.764838
# Starting prediction...
# Total elapsed time: 0.683864
# Starting prediction...
# Total elapsed time: 0.687368
# Starting prediction...
# Total elapsed time: 0.693255
# Starting prediction...
# Total elapsed time: 0.704535
# Starting prediction...
# Total elapsed time: 0.790338
# Starting prediction...
# Total elapsed time: 2.13247
# Starting prediction...
# Total elapsed time: 6.03074
# Starting prediction...
# Total elapsed time: 7.43466
# Starting prediction...
# Total elapsed time: 8.06417
# Total elapsed time: 8.06426
# Starting prediction...
# Total elapsed time: 6.88595
# ========================================================================
# AUROC:  0.8592726696556419
# ========================================================================
# ===========AURO Computed============================
# AUROC computed  [0.8759063730450851, 0.834281918085822, 0.8639090251861116, 0.8749092044035864, 0.8639600447188062, 0.8510699703494872, 0.8355436386335263, 0.8627673059317857, 0.8669877090598762, 0.8592726696556419]
# AUROC ===== 85.8860785906973 +/- 1.3746182275914889
# ========================================================================

# %%
MODEL_SAVE_PATH = PROJECT_DIR+"oc-svm.h"
ocsvm.dump_model(MODEL_SAVE_PATH)
# Out:
# Model saved in /home/thinhbka/Desktop/oc-nn/oc-svm.h
